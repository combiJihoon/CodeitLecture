# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Data/titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
new = df.loc[:, ['Age', 'Fare']]
new
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
new.plot(kind = 'line', x = 'Age', y = 'Fare')

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
a = df.loc[:, ['Survived', 'Pclass']]
a
# Out:
#      Survived  Pclass
# 0           0       3
# 1           1       1
# 2           1       3
# 3           1       1
# 4           0       3
# ..        ...     ...
# 886         0       2
# 887         1       1
# 888         0       3
# 889         1       1
# 890         0       3
#
# [891 rows x 2 columns]

# %%
survived = a[a['Survived'] == 1]
survived
# Out:
#      Survived  Pclass
# 1           1       1
# 2           1       3
# 3           1       1
# 8           1       3
# 9           1       2
# ..        ...     ...
# 875         1       3
# 879         1       1
# 880         1       2
# 887         1       1
# 889         1       1
#
# [342 rows x 2 columns]

# %%
survived['Pclass'].value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
b = df.loc[:, ['Survived', 'Age']]
b
# Out:
#      Survived   Age
# 0           0  22.0
# 1           1  38.0
# 2           1  26.0
# 3           1  35.0
# 4           0  35.0
# ..        ...   ...
# 886         0  27.0
# 887         1  19.0
# 888         0   NaN
# 889         1  26.0
# 890         0  32.0
#
# [891 rows x 2 columns]

# %%
b['Age'].plot(kind='hist')

# %%
survived_df = df[df['Survived'] == 1]
survived_df
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 875          876         1       3
# 879          880         1       1
# 880          881         1       2
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.violinplot(data = survived_df, y = 'Age')

# %% [markdown]
# # New Start

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.plot(kind = 'hist', y = 'Age')

# %%
df[['Age', 'Fare']].sort_values(by = 'Fare', ascending = False)
# Out:
#       Age      Fare
# 258  35.0  512.3292
# 737  35.0  512.3292
# 679  36.0  512.3292
# 88   23.0  263.0000
# 27   19.0  263.0000
# ..    ...       ...
# 633   NaN    0.0000
# 413   NaN    0.0000
# 822  38.0    0.0000
# 732   NaN    0.0000
# 674   NaN    0.0000
#
# [891 rows x 2 columns]

# %%
sns.stripplot(x = 'Survived', y = 'Age', hue = 'Sex', data = df)

# %%
sns.violinplot(x = 'Survived', y = 'Age', data = df)

# %%
sns.countplot(x = 'Pclass', data = df)

# %%
sns.boxplot(x = 'Survived', y = 'Age', data = df)

# %%
df['Survived'].value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
sns.kdeplot(df['Pclass'], df['Survived'])
