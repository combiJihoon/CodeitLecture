# %%
# %matplotlib inline
import pandas as pd

# %%
df = pd.read_csv('Data/iphone.csv', index_col = 0)
df
# Out:
#                       출시일  디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7  2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5  3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5  3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8  3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8  4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5  4GB  iOS 12.0     Yes

# %%
df.loc['iPhone 8', '메모리']
# Out:
# '2GB'

# %%
df.loc['iPhone 8', '메모리'] = '2.5GB'

# %%
df
# Out:
#                       출시일  디스플레이    메모리     출시 버전 Face ID
# iPhone 7       2016-09-16    4.7    2GB  iOS 10.0      No
# iPhone 7 Plus  2016-09-16    5.5    3GB  iOS 10.0      No
# iPhone 8       2017-09-22    4.7  2.5GB  iOS 11.0      No
# iPhone 8 Plus  2017-09-22    5.5    3GB  iOS 11.0      No
# iPhone X       2017-11-03    5.8    3GB  iOS 11.1     Yes
# iPhone XS      2018-09-21    5.8    4GB  iOS 12.0     Yes
# iPhone XS Max  2018-09-21    6.5    4GB  iOS 12.0     Yes

# %%
df.loc['iPhone 8']
# Out:
# 출시일        2017-09-22
# 디스플레이             4.7
# 메모리             2.5GB
# 출시 버전        iOS 11.0
# Face ID            No
# Name: iPhone 8, dtype: object

# %%
df.loc['iPhone 8'] = ['2017-09-09', '5.3', '200GB', 'iOS 100.0', 'Yes']
df
# Out:
#                       출시일 디스플레이    메모리      출시 버전 Face ID
# iPhone 7       2016-09-16   4.7    2GB   iOS 10.0      No
# iPhone 7 Plus  2016-09-16   5.5    3GB   iOS 10.0      No
# iPhone 8       2017-09-09   5.3  200GB  iOS 100.0     Yes
# iPhone 8 Plus  2017-09-22   5.5    3GB   iOS 11.0      No
# iPhone X       2017-11-03   5.8    3GB   iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8    4GB   iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5    4GB   iOS 12.0     Yes

# %%
df['Face ID'] = 'Yes'
df
# Out:
#                       출시일 디스플레이    메모리      출시 버전 Face ID
# iPhone 7       2016-09-16   4.7    2GB   iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16   5.5    3GB   iOS 10.0     Yes
# iPhone 8       2017-09-09   5.3  200GB  iOS 100.0     Yes
# iPhone 8 Plus  2017-09-22   5.5    3GB   iOS 11.0     Yes
# iPhone X       2017-11-03   5.8    3GB   iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8    4GB   iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5    4GB   iOS 12.0     Yes

# %% [markdown]
# 한꺼번에 값을 바꾸고 싶은 경우 리스트를 쓰지 않고 값만 지정하면 됨~!

# %%
df['Face ID'] = ['Yes','No','Yes','Noo','Yes','Yes','Yes']
df
# Out:
#                       출시일 디스플레이    메모리      출시 버전 Face ID
# iPhone 7       2016-09-16   4.7    2GB   iOS 10.0     Yes
# iPhone 7 Plus  2016-09-16   5.5    3GB   iOS 10.0      No
# iPhone 8       2017-09-09   5.3  200GB  iOS 100.0     Yes
# iPhone 8 Plus  2017-09-22   5.5    3GB   iOS 11.0     Noo
# iPhone X       2017-11-03   5.8    3GB   iOS 11.1     Yes
# iPhone XS      2018-09-21   5.8    4GB   iOS 12.0     Yes
# iPhone XS Max  2018-09-21   6.5    4GB   iOS 12.0     Yes

# %%
df[['디스플레이', 'Face ID']] = 'x'
df
# Out:
#                       출시일 디스플레이    메모리      출시 버전 Face ID
# iPhone 7       2016-09-16     x    2GB   iOS 10.0       x
# iPhone 7 Plus  2016-09-16     x    3GB   iOS 10.0       x
# iPhone 8       2017-09-09     x  200GB  iOS 100.0       x
# iPhone 8 Plus  2017-09-22     x    3GB   iOS 11.0       x
# iPhone X       2017-11-03     x    3GB   iOS 11.1       x
# iPhone XS      2018-09-21     x    4GB   iOS 12.0       x
# iPhone XS Max  2018-09-21     x    4GB   iOS 12.0       x

# %%
df.loc[['iPhone 8', 'iPhone X']] ='o'
df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7       2016-09-16     x  2GB  iOS 10.0       x
# iPhone 7 Plus  2016-09-16     x  3GB  iOS 10.0       x
# iPhone 8                o     o    o         o       o
# iPhone 8 Plus  2017-09-22     x  3GB  iOS 11.0       x
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
df.loc['iPhone 7': 'iPhone X'] ='o'
df
# Out:
#                       출시일 디스플레이  메모리     출시 버전 Face ID
# iPhone 7                o     o    o         o       o
# iPhone 7 Plus           o     o    o         o       o
# iPhone 8                o     o    o         o       o
# iPhone 8 Plus           o     o    o         o       o
# iPhone X                o     o    o         o       o
# iPhone XS      2018-09-21     x  4GB  iOS 12.0       x
# iPhone XS Max  2018-09-21     x  4GB  iOS 12.0       x

# %%
df.iloc['iPhone 7': 'iPhone X'] ='o'
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-4842e8cb0ae7> in <module>
# ----> 1 df.iloc['iPhone 7': 'iPhone X'] ='o'
#       2 df
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     668         else:
#     669             key = com.apply_if_callable(key, self.obj)
# --> 670         indexer = self._get_setitem_indexer(key)
#     671         self._setitem_with_indexer(indexer, value)
#     672
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_setitem_indexer(self, key)
#     655         axis = self.axis or 0
#     656         try:
# --> 657             return self._convert_to_indexer(key, axis=axis)
#     658         except TypeError as e:
#     659
#
# ...
