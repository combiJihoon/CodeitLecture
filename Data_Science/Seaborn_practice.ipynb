# %%
# %matplotlib inline

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('Data/young_survey.csv')
df.corr()
# Out:
#                                Music  Slow songs or fast songs     Dance  \
# Music                       1.000000                  0.075426  0.066719
# Slow songs or fast songs    0.075426                  1.000000  0.188217
# Dance                       0.066719                  0.188217  1.000000
# Folk                        0.027648                 -0.062023  0.065863
# Country                    -0.014272                 -0.072138  0.055106
# ...                              ...                       ...       ...
# Spending on healthy eating  0.073037                 -0.027398  0.026210
# Age                        -0.078058                  0.010998  0.031215
# Height                     -0.068002                  0.106873 -0.012681
# Weight                     -0.128233                  0.125870  0.014024
# Number of siblings         -0.011585                  0.002352  0.003952
#
#                                 Folk   Country  Classical music   Musical  \
# ...

# %%
brunch_df = df.corr()['Getting up']
brunch_df
# Out:
# Music                         0.090009
# Slow songs or fast songs     -0.052613
# Dance                         0.027249
# Folk                         -0.049612
# Country                      -0.025315
#                                 ...
# Spending on healthy eating   -0.084574
# Age                          -0.119888
# Height                       -0.031602
# Weight                       -0.054865
# Number of siblings           -0.057354
# Name: Getting up, Length: 139, dtype: float64

# %%
brunch_df['Slow songs or fast songs':'Opera'].sort_values(ascending = True)
# Out:
# Opera                      -0.071819
# Slow songs or fast songs   -0.052613
# Folk                       -0.049612
# Punk                       -0.029189
# Metal or Hardrock          -0.026769
# Country                    -0.025315
# Latino                     -0.015060
# Reggae, Ska                -0.008434
# Musical                     0.011869
# Classical music             0.014285
# Swing, Jazz                 0.019556
# Techno, Trance              0.019863
# Dance                       0.027249
# Alternative                 0.027540
# Rock n roll                 0.028889
# Hiphop, Rap                 0.038980
# Pop                         0.079101
# Rock                        0.105245
# Name: Getting up, dtype: float64

# %%
music_df = df.loc[:, 'Slow songs or fast songs':'Opera']
music_df
# Out:
#      Slow songs or fast songs  Dance  Folk  Country  Classical music  Musical  \
# 0                         3.0    2.0   1.0      2.0              2.0      1.0
# 1                         4.0    2.0   1.0      1.0              1.0      2.0
# 2                         5.0    2.0   2.0      3.0              4.0      5.0
# 3                         3.0    2.0   1.0      1.0              1.0      1.0
# 4                         3.0    4.0   3.0      2.0              4.0      3.0
# ..                        ...    ...   ...      ...              ...      ...
# 992                       2.0    5.0   2.0      2.0              5.0      4.0
# 993                       4.0    5.0   1.0      3.0              4.0      1.0
# 994                       3.0    1.0   1.0      2.0              2.0      2.0
# 995                       3.0    3.0   3.0      1.0              3.0      1.0
# 996                       5.0    4.0   3.0      2.0              3.0      3.0
#
# ...

# %%
music_df['Getting up'] = df['Getting up']

# %%
music_df
# Out:
#      Slow songs or fast songs  Dance  Folk  Country  Classical music  Musical  \
# 0                         3.0    2.0   1.0      2.0              2.0      1.0
# 1                         4.0    2.0   1.0      1.0              1.0      2.0
# 2                         5.0    2.0   2.0      3.0              4.0      5.0
# 3                         3.0    2.0   1.0      1.0              1.0      1.0
# 4                         3.0    4.0   3.0      2.0              4.0      3.0
# ..                        ...    ...   ...      ...              ...      ...
# 992                       2.0    5.0   2.0      2.0              5.0      4.0
# 993                       4.0    5.0   1.0      3.0              4.0      1.0
# 994                       3.0    1.0   1.0      2.0              2.0      2.0
# 995                       3.0    3.0   3.0      1.0              3.0      1.0
# 996                       5.0    4.0   3.0      2.0              3.0      3.0
#
# ...

# %%
music_df.corr()
# Out:
#                           Slow songs or fast songs     Dance      Folk  \
# Slow songs or fast songs                  1.000000  0.188217 -0.062023
# Dance                                     0.188217  1.000000  0.065863
# Folk                                     -0.062023  0.065863  1.000000
# Country                                  -0.072138  0.055106  0.391850
# Classical music                          -0.159021 -0.093125  0.366988
# Musical                                  -0.078479  0.067430  0.263987
# Pop                                       0.054375  0.424794  0.023641
# Rock                                     -0.018347 -0.147867  0.056471
# Metal or Hardrock                         0.050913 -0.241477  0.062454
# Punk                                      0.061916 -0.160938  0.022925
# Hiphop, Rap                               0.145154  0.372102 -0.086204
# Reggae, Ska                               0.038780  0.096751  0.120832
# ...

# %%
sns.heatmap(music_df.corr())
